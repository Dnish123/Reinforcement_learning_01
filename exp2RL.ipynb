# %%
#Random Selection

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
print("Danish Ansari || 221A027 || 01")
# Out:
# Danish Ansari || 221A027 || 01

# %%
df = pd.read_csv('/content/Ads_Optimisation.csv')
print("Danish Ansari || 221A027 || 01")
# Out:
# Danish Ansari || 221A027 || 01

# %%
df.head()
print("Danish Ansari || 221A027 || 01")
# Out:
# Danish Ansari || 221A027 || 01

# %%
print("Danish Ansari || 221A027 || 01")
import random
N =10000
d = 10
ads_selected_random =[ ]
total_reward_random= 0
for n in range(0,N):
  ad = random.randrange(d)
  ads_selected_random.append(ad)
  reward = df.values[n,ad]
  total_reward_random = total_reward_random + reward
# Out:
# Danish Ansari || 221A027 || 01

# %% [markdown]
# USING RAndom approach

# %%
total_reward_random
print("Danish Ansari || 221A027 || 01")
# Out:
# Danish Ansari || 221A027 || 01

# %%
print("Danish Ansari || 221A027 || 01")
import math
import pandas as pd

# Implementing UCB
N = 10000
d = 10
ads_selected = []
numbers_of_selections = [0] * d
sums_of_reward = [0] * d
total_reward = 0

for n in range(0, N):
    ad = 0
    max_upper_bound = 0
    for i in range(0, d):
        if (numbers_of_selections[i] > 0):
            average_reward = sums_of_reward[i] / numbers_of_selections[i]
            # Calculating the confidence interval (delta)
            delta_i = math.sqrt(3/2 * math.log(n + 1) / numbers_of_selections[i])
            upper_bound = average_reward + delta_i
        else:
            # High value to ensure every ad is selected at least once at the start
            upper_bound = 1e400

        if upper_bound > max_upper_bound:
            max_upper_bound = upper_bound
            ad = i

    # --- Updating variables ---
    ads_selected.append(ad)
    numbers_of_selections[ad] += 1
    reward = df.values[n, ad]
    sums_of_reward[ad] += reward
    total_reward += reward
# Out:
# Danish Ansari || 221A027 || 01

# %%
print("Danish Ansari || 221A027 || 01")
print(f"Total reward UCB {total_reward}")
# Out:
# Danish Ansari || 221A027 || 01
# Total reward UCB 2178

# %%
print("Danish Ansari || 221A027 || 01")
total_reward
# Out:
# Danish Ansari || 221A027 || 01
# np.int64(2178)

# %%
print("Danish Ansari || 221A027 || 01")
pd.Series(ads_selected).tail(1000).value_counts()
# Out:
# Danish Ansari || 221A027 || 01
# 4    871
# 0     52
# 1     22
# 3     18
# 7     16
# 6      9
# 5      3
# 2      3
# 9      3
# 8      3
# Name: count, dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
